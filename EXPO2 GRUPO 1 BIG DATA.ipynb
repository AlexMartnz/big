# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn import preprocessing
from sklearn import metrics
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
import warnings
warnings.filterwarnings("ignore")

import statsmodels.api as sm
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
Data1 = 'https://raw.githubusercontent.com/Martinvicharra/me/master/7-%20number-of-countries-with-primary-data-on-prevalence-of-mental-illnesses-in-the-global-burden-of-disease-study.csv'
df1 = pd.read_csv(Data1)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-12-46e6c2568e0d> in <cell line: 2>()
#       1 Data1 = "Depression.csv"
# ----> 2 df1 = pd.read_csv("Depression.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
print(Data1)
# Out:
# Depression.csv

# %%
# Función de descripción de la datasets
def describe(df):


    variables = []
    dtypes = []
    count = []
    unique = []
    missing = []


    for item in df.columns:
        variables.append(item)
        dtypes.append(df[item].dtype)
        count.append(len(df[item]))
        unique.append(len(df[item].unique()))
        missing.append(df[item].isna().sum())
    output = pd.DataFrame({
        'variable': variables,
        'dtype': dtypes,
        'count': count,
        'unique': unique,
        'missing value': missing
    })

    return output

# %%
class color:
   BLUE = '\033[94m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

# %%
print(color.BOLD + color.BLUE + color.UNDERLINE +
      '"The describe table of df1 : Mental illness dataframe"' + color.END)

print(describe(df1))
# Out:
# "The describe table of df1 : Mental illness dataframe"
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-8a59e03fa1e9> in <cell line: 4>()
#       2       '"The describe table of df1 : Mental illness dataframe"' + color.END)
#       3
# ----> 4 print(describe(df1))
#
# NameError: name 'df1' is not defined

# %%
describe(df1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-a03b6ad91d66> in <cell line: 1>()
# ----> 1 describe(df1)
#
# NameError: name 'df1' is not defined

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-18-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     130   )
#     131   if ephemeral:
# --> 132     _message.blocking_request(
#     133         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
# ...

# %%
#Propiedad

# Función de descripción de la datasets
def describe(df):


    variables = []
    dtypes = []
    count = []
    unique = []
    missing = []


    for item in df.columns:
        variables.append(item)
        dtypes.append(df[item].dtype)
        count.append(len(df[item]))
        unique.append(len(df[item].unique()))
        missing.append(df[item].isna().sum())


    output = pd.DataFrame({
        'variable': variables,
        'dtype': dtypes,
        'count': count,
        'unique': unique,
        'missing value': missing
    })

    return output

# %%
class color:
   BLUE = '\033[94m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

# %%
print(color.BOLD + color.BLUE + color.UNDERLINE +
      '"The describe table of df1 : Mental illness dataframe"' + color.END)

print(describe(df1))
# Out:
# "The describe table of df1 : Mental illness dataframe"
#                                             variable    dtype  count  unique  \
# 0                                             Entity   object     15      15
# 1                                               Code  float64     15       1
# 2                                               Year    int64     15       1
# 3  Number of countries with primary data on preva...    int64     15      11
#
#    missing value
# 0              0
# 1             15
# 2              0
# 3              0

# %%
df1.sort_values(by= "Number of countries with primary data on prevalence of mental disorders" ,inplace=True)
plt.figure(dpi=200)

# %%
df1
# Out:
#                                       Entity  Code  Year  \
# 13                  Other drug use disorders   NaN  2019
# 14                     Personality disorders   NaN  2019
# 2                           Anorexia nervosa   NaN  2019
# 7                            Bulimia nervosa   NaN  2019
# 12                      Opioid use disorders   NaN  2019
# 5                  Autism spectrum disorders   NaN  2019
# 10                                 Dysthymia   NaN  2019
# 6                           Bipolar disorder   NaN  2019
# 0                      Alcohol use disorders   NaN  2019
# 1                  Amphetamine use disorders   NaN  2019
# 3                          Anxiety disorders   NaN  2019
# 9                      Cocaine use disorders   NaN  2019
# 11                 Major depressive disorder   NaN  2019
# 8                     Cannabis use disorders   NaN  2019
# 4   Attention-deficit hyperactivity disorder   NaN  2019
#
# ...

# %%
print('Cantidad de Filas y columnas:',df1.shape)
print('Nombre columnas:',df1.columns)
# Out:
# Cantidad de Filas y columnas: (15, 4)
# Nombre columnas: Index(['Entity', 'Code', 'Year',
#        'Number of countries with primary data on prevalence of mental disorders'],
#       dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 13 to 4
# Data columns (total 4 columns):
#  #   Column                                                                   Non-Null Count  Dtype
# ---  ------                                                                   --------------  -----
#  0   Entity                                                                   15 non-null     object
#  1   Code                                                                     0 non-null      float64
#  2   Year                                                                     15 non-null     int64
#  3   Number of countries with primary data on prevalence of mental disorders  15 non-null     int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 600.0+ bytes

# %%
df1.describe()
# Out:
#        Code    Year  \
# count   0.0    15.0
# mean    NaN  2019.0
# std     NaN     0.0
# min     NaN  2019.0
# 25%     NaN  2019.0
# 50%     NaN  2019.0
# 75%     NaN  2019.0
# max     NaN  2019.0
#
#        Number of countries with primary data on prevalence of mental disorders
# count                                          15.000000
# mean                                           56.733333
# std                                            46.172760
# min                                             2.000000
# 25%                                            31.000000
# 50%                                            41.000000
# 75%                                            63.000000
# max                                           172.000000

# %%
corr = df1.set_index('Entity').corr()
sm.graphics.plot_corr(corr, xnames=list(corr.columns))
plt.show()

# %%
df1_ar = df1[(df1["Entity"] == 'Alcohol use disorders')]

años = df1_es['Year'].unique()
pop_ar = df1_ar['Number of countries with primary data on prevalence of mental disorders'].values
pop_es = df1_es['Number of countries with primary data on prevalence of mental disorders'].values

df_plot = pd.DataFrame({'Alcohol use disorders': pop_ar,
                    'Amphetamine use disorders': pop_es},
                       index=años)
df_plot.plot(kind='bar')
# Out:
# <Axes: >

# %%
anomalies = []

# Funcion ejemplo para detección de outliers
def find_anomalies(data):
    # Set upper and lower limit to 2 standard deviation
    data_std = data.std()
    data_mean = data.mean()
    anomaly_cut_off = data_std * 2
    lower_limit  = data_mean - anomaly_cut_off
    upper_limit = data_mean + anomaly_cut_off
    print(lower_limit.iloc[0])
    print(upper_limit.iloc[0])

    # Generate outliers
    for index, row in data.iterrows():
        outlier = row # # obtener primer columna
        # print(outlier)
        if (outlier.iloc[0] > upper_limit.iloc[0]) or (outlier.iloc[0] < lower_limit.iloc[0]):
            anomalies.append(index)
    return anomalies

find_anomalies(df1_espanol.set_index('Entity')[['Number of countries with primary data on prevalence of mental disorders']])
# Out:
# -35.612187608915065
# 149.07885427558173
# ['Attention-deficit hyperactivity disorder']

# %%
print(df1.head(5))
df1_es = df1[df1["Entity"] == 'Amphetamine use disorders' ]
print(df1_es.head())
df1.drop(['Entity'],axis=1)['Number of countries with primary data on prevalence of mental disorders'].plot(kind='bar')
# Out:
#                       Entity  Code  Year  \
# 13  Other drug use disorders   NaN  2019
# 14     Personality disorders   NaN  2019
# 2           Anorexia nervosa   NaN  2019
# 7            Bulimia nervosa   NaN  2019
# 12      Opioid use disorders   NaN  2019
#
#     Number of countries with primary data on prevalence of mental disorders
# 13                                                  2
# 14                                                  2
# 2                                                  27
# 7                                                  31
# 12                                                 31
#                       Entity  Code  Year  \
# 1  Amphetamine use disorders   NaN  2019
#
#    Number of countries with primary data on prevalence of mental disorders
# 1                                                 58
# <Axes: >

# %%
df1_espanol = df1.replace(np.nan, '', regex=True)
df1_espanol
# Out:
#                                       Entity Code  Year  \
# 13                  Other drug use disorders       2019
# 14                     Personality disorders       2019
# 2                           Anorexia nervosa       2019
# 7                            Bulimia nervosa       2019
# 12                      Opioid use disorders       2019
# 5                  Autism spectrum disorders       2019
# 10                                 Dysthymia       2019
# 6                           Bipolar disorder       2019
# 0                      Alcohol use disorders       2019
# 1                  Amphetamine use disorders       2019
# 3                          Anxiety disorders       2019
# 9                      Cocaine use disorders       2019
# 11                 Major depressive disorder       2019
# 8                     Cannabis use disorders       2019
# 4   Attention-deficit hyperactivity disorder       2019
#
# ...
